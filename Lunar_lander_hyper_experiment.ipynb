# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
# Requirement already satisfied: stable-baselines3==2.0.0a5 in /opt/anaconda3/lib/python3.9/site-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.0a5)
# Requirement already satisfied: swig in /opt/anaconda3/lib/python3.9/site-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2)) (4.2.1)
# Requirement already satisfied: huggingface_sb3 in /opt/anaconda3/lib/python3.9/site-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.0)
# Requirement already satisfied: gymnasium[box2d] in /opt/anaconda3/lib/python3.9/site-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (0.28.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.25.2)
# Requirement already satisfied: torch>=1.11 in /opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.3.0)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.5.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (4.11.3)
# Requirement already satisfied: box2d-py==2.3.5 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.3.5)
# Requirement already satisfied: pygame==2.1.3 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.1.3)
# Requirement already satisfied: huggingface-hub~=0.8 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (0.23.1)
# Requirement already satisfied: pyyaml~=6.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (6.0)
# Requirement already satisfied: wasabi in /opt/anaconda3/lib/python3.9/site-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (1.1.2)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2024.5.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (21.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (4.64.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (3.8.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.10.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.8.4)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.11.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.2.1)

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# Create environment
env = gym.make("LunarLander-v2", render_mode="rgb_array")

# Instantiate the agent
model = PPO(
    'MlpPolicy',
    env,
    verbose=1,
    learning_rate=0.0028,  # Slightly reduced from 0.0036
    n_steps=20480,         # Increased if iterations are doubled
    batch_size=512,        # Increased for greater stability and efficiency
    gamma=0.995,           # Adjusted if necessary based on task complexity
    gae_lambda=0.95,       # Evaluated based on new `n_steps`
    clip_range=0.2,
    ent_coef=0.04,         # Adjusted based on exploration needs
    n_epochs=10,              # Kept the same  
)


# Train the agent and display a progress bar
model.learn(total_timesteps=int(1200000), progress_bar=True)

# Save the agent
model.save("ppo_lunar")
#del model  # delete trained model to demonstrate loading
# Out:
# Output()
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | -175     |
# | time/              |          |
# |    fps             | 4628     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 20480    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.8        |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 4257        |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009656714 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00623     |
# |    learning_rate        | 0.0028      |
# |    loss                 | 218         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00929    |
# |    value_loss           | 819         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | -94.7        |
# | time/                   |              |
# |    fps                  | 3996         |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0110608805 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.516        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 103          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 317          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -65.9       |
# | time/                   |             |
# |    fps                  | 3865        |
# |    iterations           | 4           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013166368 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 54.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -39.2       |
# | time/                   |             |
# |    fps                  | 3884        |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016550105 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 36.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 90.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | -25.6        |
# | time/                   |              |
# |    fps                  | 3825         |
# |    iterations           | 6            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0141505245 |
# |    clip_fraction        | 0.23         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 25.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0237      |
# |    value_loss           | 58.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -1.37      |
# | time/                   |            |
# |    fps                  | 3511       |
# |    iterations           | 7          |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.01526258 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0028     |
# |    loss                 | 19.9       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0219    |
# |    value_loss           | 40.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 5.82        |
# | time/                   |             |
# |    fps                  | 3017        |
# |    iterations           | 8           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.013571841 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 15.2        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 29.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 436         |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 2568        |
# |    iterations           | 9           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.010309583 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0028      |
# |    loss                 | 11.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00773    |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 584         |
# |    ep_rew_mean          | 42.6        |
# | time/                   |             |
# |    fps                  | 2328        |
# |    iterations           | 10          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.007952136 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 6.8         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 696         |
# |    ep_rew_mean          | 59.8        |
# | time/                   |             |
# |    fps                  | 2148        |
# |    iterations           | 11          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.007633619 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 5.3         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 795         |
# |    ep_rew_mean          | 81.8        |
# | time/                   |             |
# |    fps                  | 2034        |
# |    iterations           | 12          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.008047519 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 3.87        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 838          |
# |    ep_rew_mean          | 93.9         |
# | time/                   |              |
# |    fps                  | 1948         |
# |    iterations           | 13           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0068584173 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0028       |
# |    loss                 | 4.99         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 10.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 884         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 1870        |
# |    iterations           | 14          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.007575537 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 2.04        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 8.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 915          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 1799         |
# |    iterations           | 15           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0073743137 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 2.59         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 8.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 1758        |
# |    iterations           | 16          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.010367764 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.845       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 3.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 120         |
# | time/                   |             |
# |    fps                  | 1728        |
# |    iterations           | 17          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 348160      |
# | train/                  |             |
# |    approx_kl            | 0.007905289 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 1.1         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00376    |
# |    value_loss           | 3.39        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 1707         |
# |    iterations           | 18           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0057167476 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.25         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00496     |
# |    value_loss           | 7.7          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 1695        |
# |    iterations           | 19          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.004886482 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.89        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 1184        |
# |    iterations           | 20          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.006336882 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 15.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00548    |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 1194         |
# |    iterations           | 21           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 430080       |
# | train/                  |              |
# |    approx_kl            | 0.0032940444 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.46         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00051     |
# |    value_loss           | 6.8          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 962         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 22          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.010379304 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.6         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 1.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 23          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.005446623 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.508       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000597   |
# |    value_loss           | 1.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 24           |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0067192153 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.36         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000305    |
# |    value_loss           | 4.64         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 25           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 512000       |
# | train/                  |              |
# |    approx_kl            | 0.0051868013 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 0.325        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 1.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 976          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 26           |
# |    time_elapsed         | 717          |
# |    total_timesteps      | 532480       |
# | train/                  |              |
# |    approx_kl            | 0.0073728636 |
# |    clip_fraction        | 0.071        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 0.196        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000496    |
# |    value_loss           | 0.973        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 951         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 27          |
# |    time_elapsed         | 729         |
# |    total_timesteps      | 552960      |
# | train/                  |             |
# |    approx_kl            | 0.007933092 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.79        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000698   |
# |    value_loss           | 5.41        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 951          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 28           |
# |    time_elapsed         | 982          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0065236734 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.59         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000112    |
# |    value_loss           | 7.72         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 943         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 29          |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 593920      |
# | train/                  |             |
# |    approx_kl            | 0.005132798 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.673       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000135   |
# |    value_loss           | 4.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 948         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 30          |
# |    time_elapsed         | 1009        |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.008021092 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.374       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 2.78        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 963        |
# |    ep_rew_mean          | 159        |
# | time/                   |            |
# |    fps                  | 620        |
# |    iterations           | 31         |
# |    time_elapsed         | 1023       |
# |    total_timesteps      | 634880     |
# | train/                  |            |
# |    approx_kl            | 0.00782769 |
# |    clip_fraction        | 0.0656     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0028     |
# |    loss                 | 0.483      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.000381   |
# |    value_loss           | 5.28       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 980          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 578          |
# |    iterations           | 32           |
# |    time_elapsed         | 1132         |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0068996428 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 0.451        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 1.53         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 988         |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 33          |
# |    time_elapsed         | 1144        |
# |    total_timesteps      | 675840      |
# | train/                  |             |
# |    approx_kl            | 0.009121663 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.368       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.768       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | 166         |
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 34          |
# |    time_elapsed         | 1157        |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.009888089 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.242       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 0.595       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 35          |
# |    time_elapsed         | 1169        |
# |    total_timesteps      | 716800      |
# | train/                  |             |
# |    approx_kl            | 0.015845392 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.288       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000863   |
# |    value_loss           | 0.762       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 981        |
# |    ep_rew_mean          | 167        |
# | time/                   |            |
# |    fps                  | 575        |
# |    iterations           | 36         |
# |    time_elapsed         | 1280       |
# |    total_timesteps      | 737280     |
# | train/                  |            |
# |    approx_kl            | 0.00790663 |
# |    clip_fraction        | 0.061      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.956     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0028     |
# |    loss                 | 0.185      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0029    |
# |    value_loss           | 0.568      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 37          |
# |    time_elapsed         | 1291        |
# |    total_timesteps      | 757760      |
# | train/                  |             |
# |    approx_kl            | 0.010095326 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.728       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 9.74        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 38           |
# |    time_elapsed         | 1303         |
# |    total_timesteps      | 778240       |
# | train/                  |              |
# |    approx_kl            | 0.0057497234 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 8.93         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 8.91         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 851         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 39          |
# |    time_elapsed         | 1553        |
# |    total_timesteps      | 798720      |
# | train/                  |             |
# |    approx_kl            | 0.013502094 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 4.19        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 818          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 40           |
# |    time_elapsed         | 1565         |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0061203823 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.41         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 827        |
# |    ep_rew_mean          | 136        |
# | time/                   |            |
# |    fps                  | 531        |
# |    iterations           | 41         |
# |    time_elapsed         | 1579       |
# |    total_timesteps      | 839680     |
# | train/                  |            |
# |    approx_kl            | 0.00432285 |
# |    clip_fraction        | 0.0307     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0028     |
# |    loss                 | 9.1        |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00253   |
# |    value_loss           | 25         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 860        |
# |    ep_rew_mean          | 140        |
# | time/                   |            |
# |    fps                  | 540        |
# |    iterations           | 42         |
# |    time_elapsed         | 1592       |
# |    total_timesteps      | 860160     |
# | train/                  |            |
# |    approx_kl            | 0.00788774 |
# |    clip_fraction        | 0.0623     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0028     |
# |    loss                 | 1.65       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00203   |
# |    value_loss           | 9          |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 43          |
# |    time_elapsed         | 1605        |
# |    total_timesteps      | 880640      |
# | train/                  |             |
# |    approx_kl            | 0.007152021 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0028      |
# |    loss                 | 1.31        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 6.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 897         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 44          |
# |    time_elapsed         | 1618        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.007570305 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 1.2         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 8.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 914         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 45          |
# |    time_elapsed         | 1631        |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.010085272 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 4.48        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 905         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 46          |
# |    time_elapsed         | 1644        |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.007200159 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 9.74        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 16.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 852         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 47          |
# |    time_elapsed         | 1967        |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.012851032 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.671       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 798         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 48          |
# |    time_elapsed         | 1980        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.011341905 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 7.29        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 24.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 745         |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 49          |
# |    time_elapsed         | 1993        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.002801545 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 4.2         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 50          |
# |    time_elapsed         | 2007        |
# |    total_timesteps      | 1024000     |
# | train/                  |             |
# |    approx_kl            | 0.008801873 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 5.29        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 21.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 51          |
# |    time_elapsed         | 2020        |
# |    total_timesteps      | 1044480     |
# | train/                  |             |
# |    approx_kl            | 0.006180888 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 10.6        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00334    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 746         |
# |    ep_rew_mean          | 119         |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 52          |
# |    time_elapsed         | 2034        |
# |    total_timesteps      | 1064960     |
# | train/                  |             |
# |    approx_kl            | 0.007608219 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 7.38        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 20.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 772         |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 53          |
# |    time_elapsed         | 2048        |
# |    total_timesteps      | 1085440     |
# | train/                  |             |
# |    approx_kl            | 0.007621205 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 5.76        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 11.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 536          |
# |    iterations           | 54           |
# |    time_elapsed         | 2061         |
# |    total_timesteps      | 1105920      |
# | train/                  |              |
# |    approx_kl            | 0.0069951713 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.59         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 7.65         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 878          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 55           |
# |    time_elapsed         | 2075         |
# |    total_timesteps      | 1126400      |
# | train/                  |              |
# |    approx_kl            | 0.0063550747 |
# |    clip_fraction        | 0.079        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 1.43         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 6.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 930          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 549          |
# |    iterations           | 56           |
# |    time_elapsed         | 2088         |
# |    total_timesteps      | 1146880      |
# | train/                  |              |
# |    approx_kl            | 0.0072096614 |
# |    clip_fraction        | 0.0973       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0028       |
# |    loss                 | 0.656        |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000632    |
# |    value_loss           | 2.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 57          |
# |    time_elapsed         | 2101        |
# |    total_timesteps      | 1167360     |
# | train/                  |             |
# |    approx_kl            | 0.007816528 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.405       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 1.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 58          |
# |    time_elapsed         | 2133        |
# |    total_timesteps      | 1187840     |
# | train/                  |             |
# |    approx_kl            | 0.009756143 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 13.5        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 6.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 59          |
# |    time_elapsed         | 2146        |
# |    total_timesteps      | 1208320     |
# | train/                  |             |
# |    approx_kl            | 0.012604957 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0028      |
# |    loss                 | 0.561       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 2.79        |
# -----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import imageio
import numpy as np

# Load the trained agent
env = gym.make("LunarLander-v2", render_mode="rgb_array")
model = PPO.load("ppo_lunar", env=env)

# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
print('Mean reward:', mean_reward, 'Std. reward:', std_reward)

# Test the trained agent
images = []
j = 0
vec_env = model.get_env()
obs = vec_env.reset()
img = model.env.render(mode="rgb_array")
for i in range(2000):
    images.append(img)
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    #vec_env.render()
    if dones:
        j = j + 1
        print('Episode:', j, 'Rewards:', rewards, 'Info:', info, 'Dones:', dones)
        imageio.mimsave(f"./images/ppo_lander_{j}.gif", [np.array(img) for k, img in enumerate(images) if k%2 == 0], fps=29)
        images = []
    img = model.env.render(mode="rgb_array")
vec_env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Mean reward: 276.05030539999996 Std. reward: 23.95621366326137
# Episode: 1 Rewards: [100.] Info: [{'episode': {'r': 295.930974, 'l': 227, 't': 1.009827}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 3.5619259e-02, -7.0737838e-04,  0.0000000e+00,  0.0000000e+00,
#        -3.8757985e-03,  0.0000000e+00,  1.0000000e+00,  1.0000000e+00],
#       dtype=float32)}] Dones: [ True]
# Episode: 2 Rewards: [100.] Info: [{'episode': {'r': 259.368553, 'l': 210, 't': 2.37183}, 'TimeLimit.truncated': False, 'terminal_observation': array([-2.1464253e-02, -1.1508012e-03,  0.0000000e+00,  0.0000000e+00,
#        -2.9669402e-04,  0.0000000e+00,  1.0000000e+00,  1.0000000e+00],
#       dtype=float32)}] Dones: [ True]
# Episode: 3 Rewards: [100.] Info: [{'episode': {'r': 297.968328, 'l': 309, 't': 3.681198}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.02845259, -0.00112766,  0.        ,  0.        ,  0.00241095,
#         0.        ,  1.        ,  1.        ], dtype=float32)}] Dones: [ True]
# Episode: 4 Rewards: [100.] Info: [{'episode': {'r': 313.877097, 'l': 235, 't': 5.335508}, 'TimeLimit.truncated': False, 'terminal_observation': array([-1.2985229e-03, -3.9073467e-04,  0.0000000e+00,  0.0000000e+00,
#        -2.5521810e-03,  0.0000000e+00,  1.0000000e+00,  1.0000000e+00],
#       dtype=float32)}] Dones: [ True]
# Episode: 5 Rewards: [100.] Info: [{'episode': {'r': 261.633528, 'l': 236, 't': 6.737518}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 1.01791956e-01, -1.19536160e-03,  0.00000000e+00,  0.00000000e+00,
#         6.13860611e-04,  0.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#       dtype=float32)}] Dones: [ True]
# Episode: 6 Rewards: [100.] Info: [{'episode': {'r': 280.461162, 'l': 228, 't': 8.224904}, 'TimeLimit.truncated': False, 'terminal_observation': array([-4.5700647e-02, -1.1827016e-03,  0.0000000e+00,  0.0000000e+00,
#        -2.1547274e-04,  0.0000000e+00,  1.0000000e+00,  1.0000000e+00],
#       dtype=float32)}] Dones: [ True]
# Episode: 7 Rewards: [100.] Info: [{'episode': {'r': 264.383581, 'l': 184, 't': 9.541697}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.04249067, -0.00105871,  0.        ,  0.        ,  0.00215765,
#         0.        ,  1.        ,  1.        ], dtype=float32)}] Dones: [ True]
# Episode: 8 Rewards: [100.] Info: [{'episode': {'r': 291.260413, 'l': 218, 't': 10.681248}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 2.3043251e-02, -1.3291144e-03,  0.0000000e+00,  0.0000000e+00,
#        -9.7633491e-04,  0.0000000e+00,  1.0000000e+00,  1.0000000e+00],
#       dtype=float32)}] Dones: [ True]
